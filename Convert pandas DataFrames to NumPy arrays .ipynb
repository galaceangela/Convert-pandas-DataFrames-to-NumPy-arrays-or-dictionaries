# %% [markdown]
# <a href="https://colab.research.google.com/github/galaceangela/Convert-pandas-DataFrames-to-NumPy-arrays-or-dictionaries/blob/main/Convert%20pandas%20DataFrames%20to%20NumPy%20arrays%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/galaceangela/Convert-pandas-DataFrames-to-NumPy-arrays-or-dictionaries/main/linear.csv')

# %%
df.head()
# Out:
#             x           y
# 0    0.000000  -51.000000
# 1   25.000000  -12.000000
# 2  117.583220  134.907414
# 3  108.922466  134.085180
# 4   69.887445         NaN

# %%
df.to_numpy()
# Out:
# array([[  0.        , -51.        ],
#        [ 25.        , -12.        ],
#        [117.5832198 , 134.9074137 ],
#        [108.9224662 , 134.0851795 ],
#        [ 69.88744536,          nan],
#        [ 96.83998269, 114.5306376 ],
#        [ 51.77594025,  31.37643731],
#        [ 35.01673734,   8.76463417],
#        [ 79.45764646,  73.28534128],
#        [ 45.3449093 ,  18.85986466],
#        [ 77.76713229,  72.9466086 ],
#        [ 55.85663802,  28.63728633],
#        [ 51.8290553 ,  27.18413784],
#        [ 36.07902502,  15.46895475],
#        [ 80.63255196,  77.25552457],
#        [124.4126644 , 147.817536  ],
#        [ 38.88238694,  29.62914801],
#        [ 85.24501874,  92.31571653],
#        [105.4849878 , 111.063745  ],
#        [ 36.82741469,   2.79748519],
#        [ 98.61682009,  98.22796195],
#        [102.1309415 , 117.0827211 ],
#        [101.9740862 , 111.1555591 ],
#        [122.5816416 , 147.0235042 ],
#        [ 96.36839009,  99.62870641],
# ...

# %%
df.values
# Out:
# array([[  0.        , -51.        ],
#        [ 25.        , -12.        ],
#        [117.5832198 , 134.9074137 ],
#        [108.9224662 , 134.0851795 ],
#        [ 69.88744536,          nan],
#        [ 96.83998269, 114.5306376 ],
#        [ 51.77594025,  31.37643731],
#        [ 35.01673734,   8.76463417],
#        [ 79.45764646,  73.28534128],
#        [ 45.3449093 ,  18.85986466],
#        [ 77.76713229,  72.9466086 ],
#        [ 55.85663802,  28.63728633],
#        [ 51.8290553 ,  27.18413784],
#        [ 36.07902502,  15.46895475],
#        [ 80.63255196,  77.25552457],
#        [124.4126644 , 147.817536  ],
#        [ 38.88238694,  29.62914801],
#        [ 85.24501874,  92.31571653],
#        [105.4849878 , 111.063745  ],
#        [ 36.82741469,   2.79748519],
#        [ 98.61682009,  98.22796195],
#        [102.1309415 , 117.0827211 ],
#        [101.9740862 , 111.1555591 ],
#        [122.5816416 , 147.0235042 ],
#        [ 96.36839009,  99.62870641],
# ...

# %%
df.to_dict()
# Out:
# {'x': {0: 0.0,
#   1: 25.0,
#   2: 117.5832198,
#   3: 108.9224662,
#   4: 69.88744536,
#   5: 96.83998269,
#   6: 51.77594025,
#   7: 35.01673734,
#   8: 79.45764646,
#   9: 45.3449093,
#   10: 77.76713229,
#   11: 55.85663802,
#   12: 51.8290553,
#   13: 36.07902502,
#   14: 80.63255196,
#   15: 124.4126644,
#   16: 38.88238694,
#   17: 85.24501874,
#   18: 105.4849878,
#   19: 36.82741469,
#   20: 98.61682009,
#   21: 102.1309415,
#   22: 101.9740862,
#   23: 122.5816416,
#   24: 96.36839009,
#   25: 64.89044698,
#   26: 81.87156504,
#   27: 83.46634106,
#   28: 129.9988213,
#   29: 129.5934245,
#   30: 71.30088195,
#   31: 89.63463319,
#   32: 82.74502445,
#   33: 84.29777124,
#   34: 93.6549342,
#   35: 37.33160529,
#   36: 52.16604202,
#   37: 104.833943,
#   38: 106.4639932,
#   39: 79.51558318,
#   40: 41.4999434,
#   41: 113.6214443,
#   42: 90.20451127,
#   43: 52.56692661,
#   44: 40.50463433,
#   45: 43.45292157,
#   46: 122.1252001,
#   47: 55.16828222,
# ...
